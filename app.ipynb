# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import re 
import joblib
import string

# %%
fake = pd.read_csv("Fake.csv")
true = pd.read_csv("True.csv")

# %%
fake['class'] = 0
true['class'] = 1

# %%
data = pd.concat([fake,true],axis=0)

# %%
data.sample(10)
# Out:
#                                                    title  \
# 11481  MAXINE WATERS: Obama’s Left A “very, very powe...
# 18654  MEDIA IGNORES Time That Bill Clinton FIRED His...
# 13654  Pentagon confirms 'probable' North Korean miss...
# 12936  CHELSEA CLINTON Lashes Out At TRUMP “Hate Spee...
# 8576   Clinton: 'I will be there' for presidential de...
# 88      Trump Admin. Tosses Out Another Obama Rule – ...
# 7387   How the polls, including ours, missed Trump's ...
# 11540  Somalia releases jailed ex-minister and govern...
# 7140    White SC Cops Sexually Assault Black Couple D...
# 1635   China urges North Korea not to go further in a...
#
#                                                     text       subject  \
# 11481  At around the 4:00 mark in the video, Maxine p...      politics
# 18654  In its 109-year history, only one F.B.I. direc...     left-news
# 13654  WASHINGTON (Reuters) - The Pentagon said on Tu...     worldnews
# 12936  Has she seen what s going on with her mom s bu...      politics
# 8576   ASHLAND, Ohio (Reuters) - Democratic president...  politicsNews
# 88     President Donald Trump has overturned another ...          News
# 7387   NEW YORK/LONDON (Reuters) - Two days ago, poll...  politicsNews
# 11540  MOGADISHU (Reuters) - A court in Somalia on Th...     worldnews
# 7140   A video published by The Washington Post shows...          News
# 1635   UNITED NATIONS (Reuters) - China’s foreign min...  politicsNews
#
#                       date  class
# 11481          Mar 6, 2017      0
# 18654         May 10, 2017      0
# 13654   November 28, 2017       1
# 12936         Sep 23, 2016      0
# 8576        July 31, 2016       1
# 88       November 16, 2017      0
# 7387     November 9, 2016       1
# 11540   December 21, 2017       1
# 7140         April 2, 2016      0
# 1635   September 21, 2017       1

# %%
data = data.drop(['title','subject','date'],axis=1)

# %%
data.reset_index(inplace=True)

# %%
data.drop(['index'],axis=1,inplace=True)

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub('\[.*?\]',"", text) 
    text = re.sub("\\W", " ", text) 
    text = re.sub("https?:://\S+|www\.\S+", "", text) 
    text = re.sub("<.*?>+", "", text) 
    text = re.sub("[%s]" % re.escape(string.punctuation), "", text) 
    text = re.sub("\n", "", text) 
    text = re.sub("\w*\d\w*", "", text) 
    return text

# %%
# apply cleaning 
data["text"] = data["text"].apply(clean_text) #split 
x = data["text"] 
y = data["class"] 
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
vectorizer = TfidfVectorizer()
xv_train = vectorizer.fit_transform(xtrain)
xv_test = vectorizer.transform(xtest)

# %%
lr = LogisticRegression(max_iter=1000)
lr.fit(xv_train, ytrain)
# Out:
# LogisticRegression(max_iter=1000)

# %%
prediction = lr.predict(xv_test)
accuracy = lr.score(xv_test, ytest)
print("Accuracy:", accuracy)
print("Accuracy in % :", accuracy*100)
# Out:
# Accuracy: 0.9858351893095768
# Accuracy in % : 98.58351893095768

# %%
print(classification_report(ytest,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5895
#            1       0.98      0.99      0.99      5330
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
joblib.dump(vectorizer, 'vectorizer.jb')
joblib.dump(lr,"lr.jb")
# Out:
# ['lr.jb']
